# %% [markdown]
# # Tutorial on how to use the shared package

# %% [markdown]
# In your virtual environment, you can run the following command to install the shared package:
# ```bash
# pip install -e .
# ```
#
# After that, you can import the package in your Python code and use it to run the model and plot the results, as shown in the code snippets below.

# %%
from shared.models import energyscope_original_snapshot_2023
from shared.utils import run_model
from shared.plotting import plot_sankey

# %%
results = run_model(energyscope_original_snapshot_2023)
# Out:
# Gurobi 12.0.3:

# %%
plot_sankey(results, aggregate_technology=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_sankey(results, aggregate_technology=True)
#
# File ~\Desktop\EnergyScope-Quebec\shared\plotting.py:378, in plot_sankey(result, aggregate_mobility, aggregate_grid, aggregate_technology, run_id, colors)
#     376 def plot_sankey(result: Result, aggregate_mobility: bool = True, aggregate_grid: bool = True,
#     377                 aggregate_technology: bool = True, run_id: int = 0, colors: Union[Colors, dict] = None) -> go.Figure:
# --> 378     df_flow = generate_sankey_flows(result, aggregate_mobility=aggregate_mobility, aggregate_grid=aggregate_grid,
#     379                                     aggregate_technology=aggregate_technology, run_id=run_id)
#     380     return _create_sankey_figure(df_flow, Colors.cast(colors or default_colors))
#
# File ~\Desktop\EnergyScope-Quebec\shared\plotting.py:154, in generate_sankey_flows(results, aggregate_mobility, aggregate_grid, aggregate_technology, run_id)
#     134 def generate_sankey_flows(results: Result, aggregate_mobility, aggregate_grid, aggregate_technology,
#     135                           run_id) -> pd.DataFrame:
#     136     """
#     137     Processes the `Result` object to transform and filter flow data for Sankey diagram visualization.
#     138
#    (...)    151             ready for Sankey diagram visualization.
#     152     """
# --> 154     df_flow = results.postprocessing['df_monthly'].loc[results.postprocessing['df_monthly']['Run'] == run_id, :]
#     156     df_flow = df_flow.groupby(['Technologies', 'Flow']).sum().rename(columns={'Monthly_flow': 'value'}).loc[:,
#     157               ['value']].reset_index()
#     159     # Swap target and source for positive values and take absolute value
#
# KeyError: 'df_monthly'
