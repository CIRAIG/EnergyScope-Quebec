# %%
#Imports
import pickle
import os
from pathlib import Path
from shared.models import energyscope_original_snapshot_2023
from shared.utils import run_model
from shared.plotting import plot_sankey
from energyscope.models import Model

# %% [markdown]
# # Sans pointe - defaut

# %%
#2023
results_wo_peaks_2023_defaut = run_model(energyscope_original_snapshot_2023,apply_postprocessing=True)
plot_sankey(results_wo_peaks_2023_defaut)
# Out:
# Gurobi 12.0.3:

# %%
output_dir = '../03_Results'
output_path = os.path.join(output_dir, 'results_wo_peaks_2023_defaut.pkl')
os.makedirs(output_dir, exist_ok=True)

# Sauvegarde
with open(output_path, 'wb') as f:
    pickle.dump(results_wo_peaks_2023_defaut, f)

# %% [markdown]
# # Sans pointe - updates

# %%
from pathlib import Path

# 1. Définition des chemins absolus
_BASE_DIR = Path(r"C:\Users\julie\Desktop\EnergyScope-Quebec")
_UTILITIES_DIR = _BASE_DIR / 'shared' / 'utilities' / 'ES_snapshot'
_PROJECT_DIR = _BASE_DIR / 'projects' / 'peaks' / '02_Model'

energyscope_original_snapshot_2023_updates = Model([
    # --- FICHIERS DE BASE (Partagés) ---
    ('mod', str(_UTILITIES_DIR / 'QC_es_main.mod')),
    ('mod', str(_UTILITIES_DIR / 'QC_objective_function.mod')),
    ('dat', str(_UTILITIES_DIR / 'QC_data.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_mob_techs_dist_B2D.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_techs_B2D.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_mob_params.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_validation_2023.dat')),

    # --- ÉLÉMENTS DE MODÉLISATION SUPPLÉMENTAIRES (.mod) ---
    #('mod', str(_PROJECT_DIR / 'Hydro_limit_annual.mod')),
    ('mod', str(_PROJECT_DIR / 'imports_split_2023.mod')),
    # <-- La ligne 'imports_split_2023.mod' a été retirée d'ici !

    # --- DONNÉES SPÉCIFIQUES SUPPLÉMENTAIRES (.dat) ---
    ('dat', str(_PROJECT_DIR / 'imports_split_2023.dat')),
])

# %%
results_wo_peaks_2023_update = run_model(energyscope_original_snapshot_2023_updates,apply_postprocessing=True)
plot_sankey(results_wo_peaks_2023_defaut)
# Out:
# Gurobi 12.0.3:

# %%
output_dir = '../03_Results'
output_path = os.path.join(output_dir, 'results_wo_peaks_2023_update.pkl')
os.makedirs(output_dir, exist_ok=True)

# Sauvegarde
with open(output_path, 'wb') as f:
    pickle.dump(results_wo_peaks_2023_update, f)

# %% [markdown]
# # Avec 2 pointes

# %%
from pathlib import Path

# 1. Définition des chemins absolus
_BASE_DIR = Path(r"C:\Users\julie\Desktop\EnergyScope-Quebec")
_UTILITIES_DIR = _BASE_DIR / 'shared' / 'utilities' / 'ES_snapshot'
_PROJECT_DIR = _BASE_DIR / 'projects' / 'peaks' / '02_Model'

# 2. Construction du modèle unique ordonné (Avec HP et 2 Pointes - 2023)
energyscope_2_pointes = Model([
    # --- FICHIERS DE BASE (Partagés) ---
    ('mod', str(_UTILITIES_DIR / 'QC_es_main.mod')),
    ('mod', str(_UTILITIES_DIR / 'QC_objective_function.mod')),
    ('dat', str(_UTILITIES_DIR / 'QC_data.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_mob_techs_dist_B2D.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_techs_B2D.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_mob_params.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_validation_2023.dat')),

    # --- ÉLÉMENTS DE MODÉLISATION SUPPLÉMENTAIRES (.mod) ---
    ('mod', str(_PROJECT_DIR / 'HP_extra.mod')),
    ('mod', str(_PROJECT_DIR / 'peaks_extra_2023.mod')),
    ('mod', str(_PROJECT_DIR / 'HP_Winter_2023.mod')),
    ('mod', str(_PROJECT_DIR / 'Hydro_limit_annual_2023.mod')),
    ('mod', str(_PROJECT_DIR / 'imports_split_2023.mod')),

    # --- INJECTION DES DONNÉES DE POINTE AUTO-SÉCURISÉES ---
    ('mod', str(_PROJECT_DIR / 'peaks_2_2023.dat')), # Mode 'mod' car contient les scripts de union
    ('dat', str(_PROJECT_DIR / 'peaks_cpt.dat')),
    ('dat', str(_PROJECT_DIR / 'HP_Winter_2023.dat')),
    ('mod', str(_PROJECT_DIR / 'imports_split_2023.dat')),
])

# %%
results_2_peaks_2023 = run_model(energyscope_2_pointes,apply_postprocessing=True)
plot_sankey(results_2_peaks_2023)
# Out:
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.mod
# 	line 11 offset 532
# 	YEARS is not defined
# 	context:  subject to link_hp_winter_capacity {y in  >>> YEARS} <<< :
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 7 offset 204
# 	f_max needs 1 subscript, not 2
# 	context:  let f_max['YEAR_2023', 'DEC_HP_ELEC' >>> ] <<<  := 10000;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 8 offset 260
# 	f_max needs 1 subscript, not 2
# 	context:  let f_max['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 10000;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 9 offset 314
# 	f_max needs 1 subscript, not 2
# 	context:  let f_max['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 10000;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 11 offset 365
# 	f_min needs 1 subscript, not 2
# 	context:  let f_min['YEAR_2023', 'DEC_HP_ELEC' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 12 offset 419
# 	f_min needs 1 subscript, not 2
# 	context:  let f_min['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 13 offset 471
# 	f_min needs 1 subscript, not 2
# 	context:  let f_min['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 16 offset 566
# 	c_inv needs 1 subscript, not 2
# 	context:  let c_inv['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 17 offset 622
# 	c_maint needs 1 subscript, not 2
# 	context:  let c_maint['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 19 offset 676
# 	c_inv needs 1 subscript, not 2
# 	context:  let c_inv['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 20 offset 730
# 	c_maint needs 1 subscript, not 2
# 	context:  let c_maint['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 23 offset 904
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'ELECTRICITY_LV' >>> ] <<<         := -1 / cop_normal;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 24 offset 1003
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_WINTER', 'ELECTRICITY_LV' >>> ] <<<  := -1 / cop_winter;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 25 offset 1093
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_PEAK', 'ELECTRICITY_LV' >>> ] <<<    := -1 / cop_peak;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 27 offset 1189
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_WINTER', 'HEAT_LOW_T_DECEN' >>> ] <<<  := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN'];
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 27 offset 1254
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_WINTER', 'HEAT_LOW_T_DECEN'] := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN' >>> ] <<< ;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 28 offset 1327
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_PEAK', 'HEAT_LOW_T_DECEN' >>> ] <<<    := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN'];
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 28 offset 1394
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_PEAK', 'HEAT_LOW_T_DECEN']   := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN' >>> ] <<< ;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 31 offset 1496
# 	c_p_t needs 2 subscripts, not 3
# 	context:  let {p in PERIODS} c_p_t['YEAR_2023', 'DEC_HP_ELEC_WINTER',  >>> p] <<<  := 1.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 32 offset 1561
# 	c_p_t needs 2 subscripts, not 3
# 	context:  let {p in PERIODS} c_p_t['YEAR_2023', 'DEC_HP_ELEC',  >>> p] <<<         := 1.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 33 offset 1638
# 	c_p_t needs 2 subscripts, not 3
# 	context:  let {p in PERIODS} c_p_t['YEAR_2023', 'DEC_HP_ELEC_PEAK',  >>> p] <<<    := 1.0;
# Gurobi 12.0.3:

# %%
output_dir = '../03_Results'
output_path = os.path.join(output_dir, 'results_2_peaks_2023.pkl')
os.makedirs(output_dir, exist_ok=True)

# Sauvegarde
with open(output_path, 'wb') as f:
    pickle.dump(results_2_peaks_2023, f)

# %% [markdown]
# # Avec 118 pointes

# %%
from pathlib import Path

# 1. Définition des chemins absolus
_BASE_DIR = Path(r"C:\Users\julie\Desktop\EnergyScope-Quebec")
_UTILITIES_DIR = _BASE_DIR / 'shared' / 'utilities' / 'ES_snapshot'
_PROJECT_DIR = _BASE_DIR / 'projects' / 'peaks' / '02_Model'

# 2. Construction du modèle unique ordonné (Avec HP et 2 Pointes - 2023)
energyscope_118_pointes = Model([
    # --- FICHIERS DE BASE (Partagés) ---
    ('mod', str(_UTILITIES_DIR / 'QC_es_main.mod')),
    ('mod', str(_UTILITIES_DIR / 'QC_objective_function.mod')),
    ('dat', str(_UTILITIES_DIR / 'QC_data.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_mob_techs_dist_B2D.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_techs_B2D.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_mob_params.dat')),
    ('dat', str(_UTILITIES_DIR / 'QC_validation_2023.dat')),

    # --- ÉLÉMENTS DE MODÉLISATION SUPPLÉMENTAIRES (.mod) ---
    ('mod', str(_PROJECT_DIR / 'HP_extra.mod')),
    ('mod', str(_PROJECT_DIR / 'peaks_extra_2023.mod')),
    ('mod', str(_PROJECT_DIR / 'HP_Winter_2023.mod')),
    ('mod', str(_PROJECT_DIR / 'Hydro_limit_annual_2023.mod')),
    ('mod', str(_PROJECT_DIR / 'imports_split_2023.mod')),

    # --- INJECTION DES DONNÉES DE POINTE AUTO-SÉCURISÉES ---
    ('mod', str(_PROJECT_DIR / 'peaks_118_2023.dat')), # Mode 'mod' car contient les scripts de union
    ('dat', str(_PROJECT_DIR / 'peaks_cpt.dat')),
    ('dat', str(_PROJECT_DIR / 'HP_Winter_2023.dat')),
    ('mod', str(_PROJECT_DIR / 'imports_split_2023.dat')),
])

# %%
results_118_peaks_2023 = run_model(energyscope_118_pointes,apply_postprocessing=True)
plot_sankey(results_118_peaks_2023)
# Out:
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.mod
# 	line 11 offset 532
# 	YEARS is not defined
# 	context:  subject to link_hp_winter_capacity {y in  >>> YEARS} <<< :
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 7 offset 204
# 	f_max needs 1 subscript, not 2
# 	context:  let f_max['YEAR_2023', 'DEC_HP_ELEC' >>> ] <<<  := 10000;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 8 offset 260
# 	f_max needs 1 subscript, not 2
# 	context:  let f_max['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 10000;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 9 offset 314
# 	f_max needs 1 subscript, not 2
# 	context:  let f_max['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 10000;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 11 offset 365
# 	f_min needs 1 subscript, not 2
# 	context:  let f_min['YEAR_2023', 'DEC_HP_ELEC' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 12 offset 419
# 	f_min needs 1 subscript, not 2
# 	context:  let f_min['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 13 offset 471
# 	f_min needs 1 subscript, not 2
# 	context:  let f_min['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 16 offset 566
# 	c_inv needs 1 subscript, not 2
# 	context:  let c_inv['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 17 offset 622
# 	c_maint needs 1 subscript, not 2
# 	context:  let c_maint['YEAR_2023', 'DEC_HP_ELEC_WINTER' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 19 offset 676
# 	c_inv needs 1 subscript, not 2
# 	context:  let c_inv['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 20 offset 730
# 	c_maint needs 1 subscript, not 2
# 	context:  let c_maint['YEAR_2023', 'DEC_HP_ELEC_PEAK' >>> ] <<<  := 0.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 23 offset 904
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'ELECTRICITY_LV' >>> ] <<<         := -1 / cop_normal;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 24 offset 1003
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_WINTER', 'ELECTRICITY_LV' >>> ] <<<  := -1 / cop_winter;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 25 offset 1093
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_PEAK', 'ELECTRICITY_LV' >>> ] <<<    := -1 / cop_peak;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 27 offset 1189
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_WINTER', 'HEAT_LOW_T_DECEN' >>> ] <<<  := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN'];
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 27 offset 1254
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_WINTER', 'HEAT_LOW_T_DECEN'] := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN' >>> ] <<< ;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 28 offset 1327
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_PEAK', 'HEAT_LOW_T_DECEN' >>> ] <<<    := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN'];
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 28 offset 1394
# 	layers_in_out needs 2 subscripts, not 3
# 	context:  let layers_in_out['YEAR_2023', 'DEC_HP_ELEC_PEAK', 'HEAT_LOW_T_DECEN']   := layers_in_out['YEAR_2023', 'DEC_HP_ELEC', 'HEAT_LOW_T_DECEN' >>> ] <<< ;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 31 offset 1496
# 	c_p_t needs 2 subscripts, not 3
# 	context:  let {p in PERIODS} c_p_t['YEAR_2023', 'DEC_HP_ELEC_WINTER',  >>> p] <<<  := 1.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 32 offset 1561
# 	c_p_t needs 2 subscripts, not 3
# 	context:  let {p in PERIODS} c_p_t['YEAR_2023', 'DEC_HP_ELEC',  >>> p] <<<         := 1.0;
# Warning:
# 	C:\Users\julie\Desktop\EnergyScope-Quebec\projects\peaks\02_Model\HP_Winter_2023.dat
# 	line 33 offset 1638
# 	c_p_t needs 2 subscripts, not 3
# 	context:  let {p in PERIODS} c_p_t['YEAR_2023', 'DEC_HP_ELEC_PEAK',  >>> p] <<<    := 1.0;
# Gurobi 12.0.3:

# %%
output_dir = '../03_Results'
output_path = os.path.join(output_dir, 'results_118_peaks_2023.pkl')
os.makedirs(output_dir, exist_ok=True)

# Sauvegarde
with open(output_path, 'wb') as f:
    pickle.dump(results_118_peaks_2023, f)
